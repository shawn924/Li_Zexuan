# %% [markdown]
# 电商用户价值分层与精准营销策略项目
#
# 电商运营痛点：1. 预算投给谁？/ 2. 优惠券给谁有效？/ 3. 哪些用户值得维护？ / 4. 哪些用户在流失要挽回？
#
# 传统RFM：Recency最近购买时间:时间越短，活跃度越高；Frequency购买频率：次数越多，用户忠诚度越高；Monetary消费金额：金额越大，用户价值越大。
#
#
# 两大局限：1.无法识别“高潜观望者” 2.忽略购买力背景差异（月薪5w和5k买同样价值的东西）

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# 数据加载与预处理函数
def load_and_preprocess(file):
    """数据加载与预处理"""
    df = pd.read_excel(file)
    
    # 数据质量检查
    print("=" * 60)
    print("第一阶段：数据质量检查")
    print("=" * 60)
    print(f"数据规模: {df.shape[0]} 行 x {df.shape[1]} 列")
    print(f"缺失值: {df.isnull().sum().sum()}")
    
    # 异常值处理
    age_outliers = df[(df['Age'] < 10) | (df['Age'] > 100)].shape[0]
    print(f"年龄异常值: {age_outliers}")    
    return df

# 执行数据加载
df = load_and_preprocess("user_personalized_features")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 19
#      16     return df
#      18 # 执行数据加载
# ---> 19 df = load_and_preprocess("user_personalized_features")
#      20 df.head()
#
# Cell In[2], line 4, in load_and_preprocess(file)
#       2 def load_and_preprocess(file):
#       3     """数据加载与预处理"""
# ----> 4     df = pd.read_excel(file)
#       6     # 数据质量检查
#       7     print("=" * 60)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
# ...
